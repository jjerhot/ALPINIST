# %% [markdown]
# # Overview plot of beam dump sensitivities to a Heavy Neutral Lepton coupling to a single lepton family at a time
#
# based on standard settings (c.f. figure 12 in [2407.08673])

# %%
from hnl_overview_setup import *
plot_ComparisonPythia83()
